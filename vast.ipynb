# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go

# Load the first 1000 rows of the data from the CSV file into a Pandas DataFrame
df = pd.read_csv('./MC2/gps.csv').iloc[:1000]

# Convert the "Timestamp" column to a datetime type
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Compute the time dimension as the number of seconds since the first timestamp in the dataset
df['TimeSeconds'] = (df['Timestamp'] - df['Timestamp'].min()).dt.total_seconds()

# Create the time space cube scatter plot using Plotly
fig = px.scatter_3d(df, x='long', y='lat', z='TimeSeconds')

# Add the image to the figure
layout = go.Layout(
    images=[go.layout.Image(
        source='./MC2/MC2-tourist.jpg',
        xref="x",
        yref="y",
        x=-74.0059,
        y=40.7128,
        sizex=0.3,
        sizey=0.2,
        opacity=0.8,
        layer="below"
    )]
)

fig.update_layout(layout)

# Set the title of the plot
fig.update_layout(title='Time Space Cube Scatter Plot with Image')

# Show the plot
fig.show()

# %%
import pandas as pd
import plotly.express as px

# Load the first 1000 rows of the data from the CSV file into a Pandas DataFrame
df = pd.read_csv('./MC2/gps.csv').iloc[:1000]

# Create the scatter plot using Plotly
fig = px.scatter(df, x='long', y='lat')

# Add the image as a background to the plot
fig.update_layout(
    images=[dict(
        source='./MC2/MC2-tourist.jpg',
        xref="x",
        yref="y",
        x=df['long'].min(),
        y=df['lat'].min(),
        sizex=df['long'].max() - df['long'].min(),
        sizey=df['lat'].max() - df['lat'].min(),
        sizing="stretch",
        opacity=0.5,
        layer="below"
    )]
)

# Set the title of the plot
fig.update_layout(title='Scatter Plot with Background Image')

# Show the plot
fig.show()
